# %% [markdown]
# # Problem Statement: Predicting Health Insurance Costs Using Data Science Techniques
#
# * The insurance industry faces a crucial challenge of accurately determining appropriate premiums for individual customers based on their associated risk. Predicting the cost of claims in an insurance company is a real-life problem that requires a more accurate and automated solution. This problem statement aims to develop a data science approach to predict health insurance costs by analyzing various factors such as BMI, age, smoking habits, health conditions, and other relevant variables.

# %% [markdown]
# ## Objective
# * The objective of this data science notebook is to leverage advanced techniques and algorithms to build a predictive model that accurately estimates the cost of health insurance claims. By utilizing a comprehensive dataset of customer information, including health-related factors, the model will assist insurance companies in making informed management decisions and generating accurate financial statements.

# %% [markdown]
# ## Proposed Solution
# * The proposed solution will involve data preprocessing, exploratory data analysis, feature engineering, and the application of suitable machine learning algorithms. By developing a robust predictive model, insurance companies will gain valuable insights into the factors influencing health insurance costs. This will enable them to optimize premium pricing, allocate resources effectively, and improve risk management strategies.

# %%
#Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.decomposition import PCA
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error

# %%
#reading the dataset

# %%
df = pd.read_csv('healthinsurance.csv')
df.head()
# Out:
#     age     sex  weight   bmi hereditary_diseases  no_of_dependents  smoker
# 0  60.0    male      64  24.3           NoDisease                 1       0  \
# 1  49.0  female      75  22.6           NoDisease                 1       0
# 2  32.0  female      64  17.8            Epilepsy                 2       1
# 3  61.0  female      53  36.4           NoDisease                 1       1
# 4  19.0  female      50  20.6           NoDisease                 0       0
#
#           city  bloodpressure  diabetes  regular_ex    job_title    claim
# 0      NewYork             72         0           0        Actor  13112.6
# 1       Boston             78         1           1     Engineer   9567.0
# 2  Phildelphia             88         1           1  Academician  32734.2
# 3    Pittsburg             72         1           0         Chef  48517.6
# 4      Buffalo             82         1           0   HomeMakers   1731.7

# %%
df.shape
# Out:
# (15000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  14604 non-null  float64
#  1   sex                  15000 non-null  object
#  2   weight               15000 non-null  int64
#  3   bmi                  14044 non-null  float64
#  4   hereditary_diseases  15000 non-null  object
#  5   no_of_dependents     15000 non-null  int64
#  6   smoker               15000 non-null  int64
#  7   city                 15000 non-null  object
#  8   bloodpressure        15000 non-null  int64
#  9   diabetes             15000 non-null  int64
#  10  regular_ex           15000 non-null  int64
#  11  job_title            15000 non-null  object
#  12  claim                15000 non-null  float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#                 age        weight           bmi  no_of_dependents
# count  14604.000000  15000.000000  14044.000000      15000.000000  \
# mean      39.547521     64.909600     30.266413          1.129733
# std       14.015966     13.701935      6.122950          1.228469
# min       18.000000     34.000000     16.000000          0.000000
# 25%       27.000000     54.000000     25.700000          0.000000
# 50%       40.000000     63.000000     29.400000          1.000000
# 75%       52.000000     76.000000     34.400000          2.000000
# max       64.000000     95.000000     53.100000          5.000000
#
#              smoker  bloodpressure      diabetes    regular_ex         claim
# count  15000.000000   15000.000000  15000.000000  15000.000000  15000.000000
# mean       0.198133      68.650133      0.777000      0.224133  13401.437620
# std        0.398606      19.418515      0.416272      0.417024  12148.239619
# min        0.000000       0.000000      0.000000      0.000000   1121.900000
# 25%        0.000000      64.000000      1.000000      0.000000   4846.900000
# 50%        0.000000      71.000000      1.000000      0.000000   9545.650000
# 75%        0.000000      80.000000      1.000000      0.000000  16519.125000
# max        1.000000     122.000000      1.000000      1.000000  63770.400000

# %%
df.describe().T
# Out:
#                     count          mean           std     min     25%
# age               14604.0     39.547521     14.015966    18.0    27.0  \
# weight            15000.0     64.909600     13.701935    34.0    54.0
# bmi               14044.0     30.266413      6.122950    16.0    25.7
# no_of_dependents  15000.0      1.129733      1.228469     0.0     0.0
# smoker            15000.0      0.198133      0.398606     0.0     0.0
# bloodpressure     15000.0     68.650133     19.418515     0.0    64.0
# diabetes          15000.0      0.777000      0.416272     0.0     1.0
# regular_ex        15000.0      0.224133      0.417024     0.0     0.0
# claim             15000.0  13401.437620  12148.239619  1121.9  4846.9
#
#                       50%        75%      max
# age                 40.00     52.000     64.0
# weight              63.00     76.000     95.0
# bmi                 29.40     34.400     53.1
# no_of_dependents     1.00      2.000      5.0
# smoker               0.00      0.000      1.0
# bloodpressure       71.00     80.000    122.0
# diabetes             1.00      1.000      1.0
# regular_ex           0.00      0.000      1.0
# claim             9545.65  16519.125  63770.4

# %% [markdown]
# ## Data cleaning

# %%
df.isna().sum()
# Out:
# age                    396
# sex                      0
# weight                   0
# bmi                    956
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
from sklearn import preprocessing
columns = ['hereditary_diseases','job_title','city','sex']  # columns names where transform is required
for X in columns:
  exec(f'le_{X} = preprocessing.LabelEncoder()')  #create label encoder with name "le_X", where X is column name
  exec(f'df.{X} = le_{X}.fit_transform(df.{X})')  #execute fit transform for column X with respective lable encoder "le_X", where X is column name
df.head()  # to display transformed results
# Out:
#     age  sex  weight   bmi  hereditary_diseases  no_of_dependents  smoker
# 0  60.0    1      64  24.3                    8                 1       0  \
# 1  49.0    0      75  22.6                    8                 1       0
# 2  32.0    0      64  17.8                    4                 2       1
# 3  61.0    0      53  36.4                    8                 1       1
# 4  19.0    0      50  20.6                    8                 0       0
#
#    city  bloodpressure  diabetes  regular_ex  job_title    claim
# 0    55             72         0           0          2  13112.6
# 1     5             78         1           1         16   9567.0
# 2    63             88         1           1          0  32734.2
# 3    64             72         1           0         10  48517.6
# 4     8             82         1           0         22   1731.7

# %% [markdown]
# ### Checking skewness of data for deciding over imputation of columns having null values

# %%
df.skew()
# Out:
# age                    0.005577
# sex                    0.040546
# weight                 0.286034
# bmi                    0.375259
# hereditary_diseases   -4.724370
# no_of_dependents       0.928935
# smoker                 1.514812
# city                  -0.063712
# bloodpressure         -1.963879
# diabetes              -1.331037
# regular_ex             1.323201
# job_title             -0.198130
# claim                  1.497829
# dtype: float64

# %% [markdown]
# #### Some features were as a string and it is not possible for a string object to work with an int/float object, and this results into lot of errors in sebsequent code. So we perform Label Encoding, where we convert all the Object-Type features to Integer-Type features.

# %% [markdown]
# ## NOTE:
# ### Deciding how to fill null values. we could have taken into consideration several ways but will majorly 2 of them, which makes sense over here.

# %% [markdown]
# ### Points to be Noted:
# 1.) Dropping missing values: If the number of missing values is relatively small compared to the total dataset and they do not significantly impact the analysis or modeling, you can simply drop the rows or columns containing missing values. However, this approach should be used with caution, as it can result in a loss of valuable information.
#
# 2.) Mean/Median/Mode imputation: For numerical features, you can fill missing values with the mean, median, or mode of the available data. This approach assumes that the missing values are missing at random and that the non-missing values provide a representative estimate for the missing values. Use mean imputation for normally distributed data and median imputation for skewed data. Mode imputation is suitable for categorical features.

# %% [markdown]
# ### Here since the data in both the columns, age & bmi have skewness between the range -0.5 to +0.5, so we can say they are fairly symmetrical and hence we proceed with filling null values with mean.

# %%
updated_df = df
updated_df['age']=updated_df['age'].fillna(updated_df['age'].mean())

updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  15000 non-null  float64
#  1   sex                  15000 non-null  int32
#  2   weight               15000 non-null  int64
#  3   bmi                  14044 non-null  float64
#  4   hereditary_diseases  15000 non-null  int32
#  5   no_of_dependents     15000 non-null  int64
#  6   smoker               15000 non-null  int64
#  7   city                 15000 non-null  int32
#  8   bloodpressure        15000 non-null  int64
#  9   diabetes             15000 non-null  int64
#  10  regular_ex           15000 non-null  int64
#  11  job_title            15000 non-null  int32
#  12  claim                15000 non-null  float64
# dtypes: float64(3), int32(4), int64(6)
# memory usage: 1.3 MB

# %%
updated_df = df
updated_df['bmi']=updated_df['bmi'].fillna(updated_df['bmi'].mean())

updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  15000 non-null  float64
#  1   sex                  15000 non-null  int32
#  2   weight               15000 non-null  int64
#  3   bmi                  15000 non-null  float64
#  4   hereditary_diseases  15000 non-null  int32
#  5   no_of_dependents     15000 non-null  int64
#  6   smoker               15000 non-null  int64
#  7   city                 15000 non-null  int32
#  8   bloodpressure        15000 non-null  int64
#  9   diabetes             15000 non-null  int64
#  10  regular_ex           15000 non-null  int64
#  11  job_title            15000 non-null  int32
#  12  claim                15000 non-null  float64
# dtypes: float64(3), int32(4), int64(6)
# memory usage: 1.3 MB

# %%
df.duplicated().sum()
# Out:
# 1096

# %%
df[df.duplicated()]
# Out:
#         age  sex  weight        bmi  hereditary_diseases  no_of_dependents
# 605    46.0    0      68  30.266413                    8                 2  \
# 608    27.0    0      82  30.266413                    8                 3
# 898    48.0    0      67  33.100000                    0                 0
# 919    26.0    1      56  23.700000                    8                 2
# 970    48.0    0      70  28.900000                    8                 1
# ...     ...  ...     ...        ...                  ...               ...
# 14966  46.0    1      46  22.300000                    8                 0
# 14971  18.0    0      53  27.300000                    8                 3
# 14987  47.0    1      94  47.500000                    8                 1
# 14989  44.0    1      90  38.100000                    8                 1
# 14997  20.0    1      62  33.300000                    8                 0
#
#        smoker  city  bloodpressure  diabetes  regular_ex  job_title    claim
# 605         0    41             60         1           0         12   8825.1
# 608         0    57             82         1           1          4  18804.8
# 898         1    15             70         1           0         24  40974.2
# 919         0    36             72         1           0         22   3484.3
# 970         0    35             72         0           0          4   9249.5
# ...       ...   ...            ...       ...         ...        ...      ...
# 14966       0    42             72         1           0          0   7147.1
# 14971       1     5             85         1           0         33  18223.5
# 14987       0    68             61         1           0          0   8083.9
# 14989       0    26             76         1           0         16   7152.7
# 14997       0    82             52         1           0         18   1391.5
#
# [1096 rows x 13 columns]

# %%
updated_df = updated_df.drop_duplicates()

# %%
updated_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## EDA

# %% [markdown]
# ### CLAIMS(target) Distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x='claim', data=updated_df, kde=True)
plt.axvline(updated_df.claim.mean(), color='r', linestyle='--', label='Mean')
plt.axvline(updated_df.claim.median(), color='g', linestyle='--', label='Median')
plt.title('Claim Distribution')
plt.xlabel('Claim')
plt.ylabel('Frequency')
plt.show()
print(f'Skewness: {updated_df["claim"].skew()}')
print(f'Mean: {(updated_df["claim"].mean())}')
print(f'Median: {updated_df["claim"].median()}')
# Out:
# Skewness: 1.489221351406612
# Mean: 13431.813744246261
# Median: 9567.0

# %% [markdown]
# ### On average, clients have claims of around 'dollar 13,431'. However, there are also clients whose claims exceed dollar 60,000, and these clients are outliers that cause the distribution of the claims column to be right-skewed with a skewness value of 1.48.

# %% [markdown]
# ### AGE distribution

# %%
plt.figure(figsize=(20, 6))
sns.histplot(x='age', data=updated_df, kde=True)
plt.axvline(updated_df.age.mean(), color='r', linestyle='--', label='Mean')
plt.axvline(updated_df.age.median(), color='g', linestyle='--', label='Median')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(20, 6))
sns.scatterplot(x='age', y='claim', data=updated_df, hue='smoker')
plt.title('Age vs Claim')
plt.xlabel('Age')
plt.ylabel('Claim')
plt.show()
print(f'Skewness: {updated_df["age"].skew()}')
print(f'Mean: {(updated_df["age"].mean()):.0f}')
print(f'Median: {updated_df["age"].median()}')
print(f'Minimum Age: {updated_df["age"].min()}')
print(f'Maximum Age: {updated_df["age"].max()}')
# Out:
# Skewness: 0.006241188212225505
# Mean: 40
# Median: 40.0
# Minimum Age: 18.0
# Maximum Age: 64.0

# %% [markdown]
# ### The distribution of the age column is classified as a normal (symmetrical) distribution with a skewness value close to 0, and the mean and median values are close to each other. It is known that the average age of the clients is around 40 years, with the youngest being 18 years old and the oldest being 64 years old. Looking at the scatter plot, it can be determined that the age column has a positive correlation with the claims column, meaning that as the client's age increases, their claims also tend to increase. It is also evident that the claims for smokers are significantly higher than those for non-smokers.

# %% [markdown]
# ### GENDER distribution

# %%
plt.figure(figsize=(15, 6))
fig = sns.countplot(x='sex', data=updated_df)
for p in fig.patches:
    height = p.get_height()
    fig.text(p.get_x() + p.get_width()/2.,height + 3, '{:1.0f}'.format(height), ha="center")
plt.title('Gender Count')
plt.xlabel('Gender')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.boxplot(x='sex', y='claim', data=updated_df)
plt.title('Claim Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Claim')
plt.show()

# %%
fig = sns.countplot(x='sex', data=updated_df, hue='smoker')
for p in fig.patches:
    height = p.get_height()
    fig.text(p.get_x() + p.get_width()/2.,height + 3, '{:1.0f}'.format(height), ha="center")
plt.title('Gender Count by Smoker')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
round(updated_df.groupby('sex').claim.mean(), 0).reset_index()
# Out:
#    sex    claim
# 0    0  12748.0
# 1    1  14143.0

# %% [markdown]
# ### The number of female and male clients is not significantly different. There are 6813 male clients and 7091 female clients. However, when looking at the range in the claim cost box plot, there is a noticeable difference. The average claims for male clients is around Dollar 14,143, while for female clients, it is around dollar 12748. This difference could possibly be due to a higher proportion of male clients being smokers compared to female clients.

# %% [markdown]
# ### BMI distribution

# %%
plt.figure(figsize=(25, 6))
sns.histplot(x='bmi', data=updated_df, kde=True)
plt.axvline(updated_df.bmi.mean(), color='r', linestyle='--', label='Mean')
plt.axvline(updated_df.bmi.median(), color='g', linestyle='--', label='Median')
plt.title('Body Mass Index Distribution')
plt.xlabel('Body Mass Index')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.scatterplot(x='bmi', y='claim', data=updated_df, hue='smoker')
plt.title('BMI vs Charges')
plt.xlabel('Body Mass Index')
plt.ylabel('Claim')
plt.show()
print(f'Skewness: {updated_df["bmi"].skew()}')
print(f'Mean: {(updated_df["bmi"].mean())}')
print(f'Median: {updated_df["bmi"].median()}')
# Out:
# Skewness: 0.390556118762522
# Mean: 30.273024873802015
# Median: 29.9

# %% [markdown]
# ### On average, clients have a BMI (Body Mass Index) of approx 30 kg/m2. The BMI follows a normal distribution with a bell-shaped curve. There are very few outliers in this column, so it is possible that the outliers in the BMI column will be left as they are. Looking at the scatter plot, the BMI parameter shows a weak positive correlation with the charges column. This means that if a customer is a non-smoker, the increase in claims is not significantly high based on their BMI. However, if a client is a smoker, the higher their body mass index, the higher their claims tends to be.

# %% [markdown]
# ### Number Of Dependents Distribution

# %%
plt.figure(figsize=(25, 6))

fig = sns.countplot(x='no_of_dependents', data=updated_df)
for p in fig.patches:
    height = p.get_height()
    fig.text(p.get_x() + p.get_width()/2.,height + 3, '{:1.0f}'.format(height), ha="center")
plt.title('No. of dependents Count')
plt.xlabel('No. Of Dependents')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.boxplot(x='no_of_dependents', y='age', data=updated_df)
plt.title('Age Distribution by No. Of dependents')
plt.xlabel('No. Of Dependents')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
sns.boxplot(x='no_of_dependents', y='claim', data=updated_df)
plt.title('Claim Distribution by no. of dependents')
plt.xlabel('No. Of Dependents')
plt.ylabel('Claim')
plt.show()
print(f'Mean: {(updated_df["no_of_dependents"].mean()):.0f}')
# Out:
# Mean: 1

# %% [markdown]
# ### The average number of dependents for these claim's customer is 1, but there are approximately 5837 clients who do not have any dependents. And based on the box plot between the "no. of dependent" column and the "claims" column, these two columns have a weak positive relationship.

# %% [markdown]
# ### SMOKER distribution

# %%
plt.figure(figsize=(25, 6))

fig = sns.countplot(x='smoker', data=updated_df)
for p in fig.patches:
    height = p.get_height()
    fig.text(p.get_x() + p.get_width()/2.,height + 3, '{:1.0f}'.format(height), ha="center")
plt.title('Smoker Count')
plt.xlabel('Smoker')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.pie(updated_df.smoker.value_counts().reindex([1, 0]), labels=updated_df.smoker.value_counts().reindex([1, 0]).index, autopct='%1.1f%%', explode=[0.1, 0], startangle=180)
plt.title('Smoker Percentage')
# Out:
# Text(0.5, 1.0, 'Smoker Percentage')

# %%
sns.boxplot(x='smoker', y='claim', data=updated_df)
plt.title('Charges Distribution by Smoker')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()
print(f"Average Charges for Smokers: ${(updated_df[updated_df.smoker == 1].claim.mean()):.0f}")
print(f"Average Charges for Non-Smokers: ${(updated_df[updated_df.smoker == 0].claim.mean()):.0f}")
# Out:
# Average Charges for Smokers: $32102
# Average Charges for Non-Smokers: $8745

# %% [markdown]
# ### The number of smokers is 11114 clients, which accounts for only about 20% of all claims. However, despite being a small proportion, the cost to be paid by a smoker is around dollar 32,102, significantly higher than non-smokers who pay dollar 8,745.

# %%
plt.figure(figsize=(25, 6))

fig = sns.countplot(x='city', data=updated_df)

for p in fig.patches:
    height = p.get_height()
    fig.text(p.get_x() + p.get_width()/2.,height + 3, '{:1.0f}'.format(height), ha="center")
plt.title('City Count')
plt.xlabel('City')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.boxplot(x='city', y='claim', data=updated_df, hue='smoker')
plt.title('Claim Distribution by City')
plt.xlabel('city')
plt.ylabel('Charges')
plt.show()

# %%
plt.figure(figsize=(15, 9))
fig = sns.countplot(x='city', data=updated_df, hue='smoker')
for p in fig.patches:
    height = p.get_height()
    fig.text(p.get_x() + p.get_width()/2.,height + 3, '{:1.0f}'.format(height), ha="center")
plt.title('City Count by Smoker')
plt.xlabel('City')
plt.ylabel('Count')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = df

hereditary_claim = data.groupby('hereditary_diseases')['claim'].sum()

job_claim = data.groupby('job_title')['claim'].sum()

plt.figure(figsize=(8, 6))
hereditary_claim.plot(kind='bar', stacked=True)
plt.xlabel('Hereditary Diseases')
plt.ylabel('Total Claim')
plt.title('Hereditary Diseases vs Claim')
plt.show()

# %% [markdown]
# #### We see people with No Disease have a significantly higher claim as compared to others. So this might be a good feature.

# %%
plt.figure(figsize=(10, 6))
job_claim.plot(kind='bar', stacked=True)
plt.xlabel('Job Title')
plt.ylabel('Total Claim')
plt.title('Job Title vs Claim')
plt.show()

# %% [markdown]
# #### The claims across Job Titles are distributed in a similar way, this still could be a good feature for Modelling. But we will leave that on  the Feature Selection technique and number of best features.

# %%
updated_df.head()
# Out:
#     age  sex  weight   bmi  hereditary_diseases  no_of_dependents  smoker
# 0  60.0    1      64  24.3                    8                 1       0  \
# 1  49.0    0      75  22.6                    8                 1       0
# 2  32.0    0      64  17.8                    4                 2       1
# 3  61.0    0      53  36.4                    8                 1       1
# 4  19.0    0      50  20.6                    8                 0       0
#
#    city  bloodpressure  diabetes  regular_ex  job_title    claim
# 0    55             72         0           0          2  13112.6
# 1     5             78         1           1         16   9567.0
# 2    63             88         1           1          0  32734.2
# 3    64             72         1           0         10  48517.6
# 4     8             82         1           0         22   1731.7

# %% [markdown]
# ### Correlation Map

# %%
corr_num = updated_df.corr()

plt.figure(figsize=(10, 6))
sns.heatmap(corr_num, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13904 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  13904 non-null  float64
#  1   sex                  13904 non-null  int64
#  2   weight               13904 non-null  int64
#  3   bmi                  13904 non-null  float64
#  4   hereditary_diseases  13904 non-null  int64
#  5   no_of_dependents     13904 non-null  int64
#  6   smoker               13904 non-null  int64
#  7   city                 13904 non-null  int64
#  8   bloodpressure        13904 non-null  int64
#  9   diabetes             13904 non-null  int64
#  10  regular_ex           13904 non-null  int64
#  11  job_title            13904 non-null  int64
#  12  claim                13904 non-null  float64
# dtypes: float64(3), int64(10)
# memory usage: 1.5 MB

# %% [markdown]
# ### Feature Selection
#
# ##### We will select top 5 features and then proceed forward with the test train split and training

# %%
features = list(updated_df.columns[:12])
print("features:", features, sep="\n")
# Out:
# features:
# ['age', 'sex', 'weight', 'bmi', 'hereditary_diseases', 'no_of_dependents', 'smoker', 'city', 'bloodpressure', 'diabetes', 'regular_ex', 'job_title']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

y = updated_df["claim"]
X = updated_df[features]

selector = SelectKBest(f_regression, k=8)
selector.fit(X, y)

X_new = selector.transform(X)
print(updated_df.columns[selector.get_support(indices=True)].tolist())
final_features = updated_df.columns[selector.get_support(indices=True)].tolist()
# Out:
# ['age', 'weight', 'bmi', 'hereditary_diseases', 'no_of_dependents', 'smoker', 'diabetes', 'regular_ex']

# %% [markdown]
# #### The top 8 features that we got are printed above. This was using the f_regression function from sklearn. The value 8 can be varied depending on how model learns and the evaluation mterics.

# %% [markdown]
# ### In this section, the data will be split into training set, validation set, and testing set with a ratio where:
#
# #### 85% of the data will be used for the training set.
# #### 10% of the data will be used for the validation set.
# #### 5% of the data will be used for the testing set.

# %%
df_train_val, df_test = train_test_split(updated_df, test_size=0.04, random_state=23)
df_train, df_val = train_test_split(df_train_val, test_size=0.1, random_state=23)

# %%
print(f'df_train proportion: {len(df_train) / len(updated_df):.2f}')
print(f'df_val proportion: {len(df_val) / len(updated_df):.2f}')
print(f'df_test proportion: {len(df_test) / len(updated_df):.2f}')
# Out:
# df_train proportion: 0.86
# df_val proportion: 0.10
# df_test proportion: 0.04

# %% [markdown]
# ### Handling The Outliers

# %%
plt.figure(figsize=(25, 6))
plt.subplot(1, 3, 1)
sns.boxplot(x='age', data=df_train)
plt.title('Age Distribution')
plt.xlabel('Frequency')
plt.subplot(1, 3, 2)
sns.boxplot(x='bmi', data=df_train)
plt.title('BMI Distribution')
plt.xlabel('Frequency')
plt.subplot(1, 3, 3)
sns.boxplot(x='claim', data=df_train)
plt.title('Claim Distribution')
plt.xlabel('Frequency')
plt.show()

# %% [markdown]
# #### Based on the three box plots of the numeric columns, it appears that there are outliers only in the "claims" column. Since the "claims" column has a skewed distribution, outlier checking will be performed using the IQR method.

# %%
# Outlier Detection For Skewed Distribution
def skewed_dis(df, col):
    IQR = df[col].quantile(0.75) - df[col].quantile(0.25)
    lower_bound = df[col].quantile(0.25) - (IQR * 1.5)
    upper_bound = df[col].quantile(0.75) + (IQR * 1.5)
    return df[(df[col] < lower_bound) | (df[col] > upper_bound)]

# %%
outliers = skewed_dis(df_train, 'claim')
print(f"Outlier percentage: {(len(outliers) / len(df_train) * 100):.1f}%")
outliers
# Out:
# Outlier percentage: 10.8%
#         age  sex  weight        bmi  hereditary_diseases  no_of_dependents
# 6197   41.0    1      80  35.800000                    8                 1  \
# 6878   40.0    0      58  32.800000                    9                 2
# 4418   43.0    1      62  38.100000                    8                 2
# 11699  59.0    0      58  36.800000                    8                 1
# 10550  43.0    1      72  36.000000                    8                 3
# ...     ...  ...     ...        ...                  ...               ...
# 2807   34.0    0      81  30.266413                    4                 1
# 9875   60.0    1      79  32.800000                    8                 0
# 14403  36.0    1      90  34.400000                    8                 0
# 6250   64.0    0      70  33.800000                    2                 1
# 12730  27.0    0      72  31.400000                    3                 0
#
#        smoker  city  bloodpressure  diabetes  regular_ex  job_title    claim
# 6197        1    42              0         1           0         13  40273.7
# 6878        1     8             70         1           0          9  40003.3
# 4418        1    45             80         1           0         12  42560.4
# 11699       1    13             56         1           0         22  47896.8
# 10550       1     3             74         1           0         28  42124.5
# ...       ...   ...            ...       ...         ...        ...      ...
# 2807        1    11             66         1           0          9  43943.9
# 9875        1     7             75         0           0         15  52590.8
# 14403       1    76             90         1           0          1  37742.6
# 6250        1    41             86         1           0         20  47928.0
# 12730       1    52             80         1           1         33  34838.9
#
# [1299 rows x 13 columns]

# %% [markdown]
# #### The table above represents the data of clients who are outliers. Approximately 10% of the clients, or 100 customers, are classified as outliers in the "df_train" dataset. From the "smoker" column, it seems that most of these outliers are smokers. An analysis will be conducted on this outlier data to draw conclusions on whether they should be removed, capped, or left as is.

# %%
plt.figure(figsize=(25, 6))
plt.subplot(1, 3, 1)
plt.pie(outliers.smoker.value_counts().reindex([1, 0]), labels=outliers.smoker.value_counts().reindex([1, 0]).index, autopct='%1.1f%%')
plt.title('Smoker Percentage')
plt.subplot(1, 3, 2)
sns.histplot(x='age', data=outliers, kde=True)
plt.axvline(outliers.age.mean(), color='r', linestyle='--', label='Mean')
plt.axvline(outliers.age.median(), color='g', linestyle='--', label='Median')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.subplot(1, 3, 3)
sns.histplot(x='bmi', data=outliers, kde=True)
plt.axvline(outliers.bmi.mean(), color='r', linestyle='--', label='Mean')
plt.axvline(outliers.bmi.median(), color='g', linestyle='--', label='Median')
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
print(f'Average Claim From Outliers: ${(outliers.claim.mean()):.0f}')
print(f'Average Age From Outliers: {outliers.age.mean():.0f}')
print(f'Average BMI From Outliers: {outliers.bmi.mean():.0f}')
# Out:
# Average Claim From Outliers: $41851
# Average Age From Outliers: 42
# Average BMI From Outliers: 34

# %% [markdown]
# #### Indeed, it is true that 97% of the clients in this outlier data are smokers with above-average age and BMI. Since almost all of these outlier clients are smokers with above-average age and BMI, it is reasonable for their insurance charges to be high. Therefore, the outliers will be left as is.

# %% [markdown]
# #### Based on the EDA results and the f_regression feature selection, the columns that will be used as features are:
#
# * Age
# * BMI
# * Smoker
# * weight
# * diabetes
# * hereditary_diseases
# * no_of_dependents
# * regular_ex
#
#
# These columns shows us the best result even in the correlation map, and hence makes it the perfect columns to be picked as feature that will help us predict the target column
#
# #### Meanwhile, the "claims" column will be the target variable.

# %% [markdown]
# ### Model Definition
# Three models will be created:
#
# * "linear": a regular Linear Regression model.
# * "poly": a Linear Regression model with Polynomial Features that will be tuned using grid search with 5-fold cross-validation.

# %%
# Training Set
X_train = df_train[final_features]
y_train = df_train.claim

# Validation Set
X_val = df_val[final_features]
y_val = df_val.claim

# %%
# Selecting the features and target variable
featuresx = final_features
targetx = 'claim'

# Creating a scatter matrix
pd.plotting.scatter_matrix(updated_df[featuresx + [targetx]], figsize=(10, 10))
plt.show()

# %% [markdown]
# ### Linear Regression

# %%
model_1 = LinearRegression()

# %%
model_1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
training_score_1 = model_1.score(X_train, y_train)

# %%
y_train_pred_1 = model_1.predict(X_train)
training_mae_1 = mean_absolute_error(y_train, y_train_pred_1)

# %%
print("Training Score: ", training_score_1)
print("Training MAE: ", training_mae_1)
# Out:
# Training Score:  0.7380016441192917
# Training MAE:  4131.9288457343955

# %% [markdown]
# ##### On validation set

# %%
model_1_v = LinearRegression()

# %%
model_1_v.fit(X_val, y_val)
# Out:
# LinearRegression()

# %%
training_score_1_v = model_1_v.score(X_val, y_val)

# %%
y_train_pred_1_v = model_1_v.predict(X_val)
training_mae_1_v = mean_absolute_error(y_val, y_train_pred_1_v)

# %%
print("Training Score: ", training_score_1_v)
print("Training MAE: ", training_mae_1_v)
# Out:
# Training Score:  0.7519511644648267
# Training MAE:  4056.13825804294

# %% [markdown]
# ## Pipeline

# %% [markdown]
# ### In this section, a pipeline will be created to perform scaling using StandardScaler(), encoding using OneHotEncoder(), and then dimensionality reduction using PCA() with n_component = 0.95. This means that the dimensions will be reduced while retaining 95% of the information from the data.

# %%
# Numeric Features Scaling
num_pipe = Pipeline([('scaling', StandardScaler())])

# Categorical Features Encoding
cat_pipe = Pipeline([('encode', OneHotEncoder(handle_unknown='ignore'))])

# Preprocessing Pipeline
preprocess = ColumnTransformer([
    ('num',num_pipe, X_train.select_dtypes(include=['float64', 'int64']).columns),
    ('cat',cat_pipe, X_train.select_dtypes(include=['object']).columns)
])

# %% [markdown]
# #### Creating a pipeline for Polynomial Regression and Extreme Gradient Boosting Regressor models.

# %%
poly_lr_pipe = Pipeline([('preprocessing', preprocess), ('pca', PCA(n_components=0.95)), ('poly', PolynomialFeatures()), ('model', LinearRegression())])

# %% [markdown]
# #### Creating a dictionary that contains hyperparameters for the Polynomial Regression and Extreme Gradient Boosting Regressor models.

# %%
poly_params = {'poly__degree': [3, 4, 5, 6]}

# %%
poly = GridSearchCV(poly_lr_pipe, param_grid=poly_params, cv=2, n_jobs=-1)

# %% [markdown]
# ### Model Training
# * After the models are created, each model will now be trained using X_train and y_train

# %%
X_train.shape
# Out:
# (12012, 8)

# %%
# %timeit poly.fit(X_train, y_train)
# Out:
# 32.5 s ± 167 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
poly.best_params_
# Out:
# {'poly__degree': 3}

# %%
print("The intercept for the model trained above is: ")
interceptx = poly.best_estimator_.named_steps.model.intercept_
print(interceptx)
# Out:
# The intercept for the model trained above is:
# 3816862840146.9497

# %%
print("The coefficients for the model trained above is: ")
coefx = poly.best_estimator_.named_steps.model.coef_
print(coefx)
# Out:
# The coefficients for the model trained above is:
# [ 3.86235800e+09 -5.08307572e+12  2.74830828e+12 -5.31397443e+10
#   5.92789863e+12 -2.12470789e+11  2.41652623e+12  1.22578764e+12
#   5.41083426e+11 -5.04839310e+10 -5.60455798e+11  1.37311364e+12
#  -3.15610153e+12 -9.66461197e+11 -9.55191507e+11 -2.58961548e+11
#   2.39053253e+12  1.99349424e+12  2.30020259e+12 -1.14287404e+12
#   2.50397798e+11 -2.05279290e+12 -6.15110355e+11 -1.31329832e+10
#  -8.46520501e+12  3.47175241e+12 -8.29420783e+12  3.12724420e+12
#  -3.51907079e+12 -1.48033225e+12  6.48612310e+12  2.83832278e+12
#   1.31608158e+12  1.51378819e+12  1.61724690e+12 -2.42910568e+12
#   2.47890648e+12 -1.29302656e+12  1.12209930e+12  4.19987926e+11
#   1.56210122e+12  3.25205731e+10 -7.56808069e+10 -2.06656111e+11
#  -2.04176740e+12  2.26682531e+11  6.97070628e+11 -1.03409191e+12
#  -1.94257136e+11 -7.73446118e+11 -4.18913733e+11 -5.88339883e+11
#  -5.12920891e+11  4.03434491e+11 -2.24998677e+12  9.66296171e+11
#  -9.46173059e+11 -3.73685539e+11 -9.21242382e+11 -1.39725962e+12
#   3.95400894e+11  4.70810316e+12  2.82753074e+12  2.49496550e+12
#   1.82369473e+12  4.13236409e+11 -1.93822608e+12  1.82452086e+12
#  -1.11786626e+12  9.34680534e+11 -1.09964217e+12  1.56844129e+12
#   1.21834416e+12  1.75553628e+12 -6.37791029e+11 -2.27905586e+09
#   8.14332864e+11  4.39835443e+11  5.56804742e+11  2.96076721e+11
#   1.24839343e+12 -8.33773402e+11 -2.12429912e+12  1.69798077e+12
#  -7.02630326e+11  1.10017598e+12 -3.64987075e+10  9.74377842e+11
#   3.68921786e+11  4.17008723e+12  2.25105601e+12  2.87740111e+12
#   1.96793823e+12  2.32920209e+12 -3.99403244e+12  2.84279518e+11
#  -2.63176919e+12 -8.07544232e+10 -2.90367727e+12  1.07772812e+12
#   9.44119329e+11  1.39622581e+12 -2.97182971e+11 -5.96131975e+11
#   2.46880205e+11 -1.01768215e+12  4.06194949e+11  2.11954505e+10
#   7.41331025e+11  3.42257910e+12 -1.11334207e+13  2.45502291e+12
#  -3.65798938e+12  1.16280369e+12  4.47850662e+11  7.47687302e+12
#  -1.15376727e+13  7.94247794e+11 -7.13343315e+12 -1.22343815e+12
#  -1.12141139e+12 -5.13321636e+12 -1.60993725e+12  4.13050753e+11
#  -5.25903694e+11 -3.10648007e+12 -1.01989370e+12 -5.77901039e+11
#  -2.61347383e+11 -9.10897362e+11 -1.51683224e+12  6.41363173e+12
#   1.34999743e+12  3.56307641e+12  1.01408430e+12 -1.21202590e+12
#   2.22766040e+12 -2.45965984e+12 -9.35965230e+11  7.95399218e+11
#   1.24956465e+12  1.39777147e+12 -8.36000451e+11  2.87713766e+11
#   1.61981622e+12 -5.22211563e+11 -1.42434228e+12 -1.27675762e+12
#  -2.23903250e+11 -3.56741875e+09 -1.74892366e+12  4.55479379e+10
#  -8.30339747e+11  9.60954258e+10  6.43828368e+11  1.17472583e+11
#   3.85488624e+10  2.64294366e+11 -5.00917081e+11  1.93379175e+10
#  -1.46966247e+11 -1.69733621e+11 -2.17595258e+10 -2.62927243e+11
#  -8.46747109e+11]

# %% [markdown]
# #### From the grid search results, the best hyperparameter for the polynomial regression model is degree 5.

# %% [markdown]
# ### Model Evaluation
# * In this section, each trained model will be evaluated using the evaluation metrics: R2 Score and Mean Absolute Error (MAE).
# ##### Polynomial Regression

# %%
print('-----------Training Set-----------')
print(f'Training Score: {poly.score(X_train, y_train):.2f}')
print(f'Training MAE: {mean_absolute_error(y_train, poly.predict(X_train)):.2f}')

print('-----------Validation Set-----------')
print(f'Validation Score: {poly.score(X_val, y_val):.2f}')
print(f'Validation MAE: {mean_absolute_error(y_val, poly.predict(X_val)):.2f}')
# Out:
# -----------Training Set-----------
# Training Score: 0.83
# Training MAE: 3082.55
# -----------Validation Set-----------
# Validation Score: 0.84
# Validation MAE: 3023.33

# %% [markdown]
# ### Model Analysis
# * From the evaluation results, the regular Linear Regression model shows slight overfitting with an R2 Score of 0.73 and MAE of 4131 on the training set, while on the validation set, it achieves an R2 Score of 0.75 and MAE of 4056. On the other hand, the Polynomial Regression model tuned using grid search with the best parameter of degree = 3 performs better. It achieves an R2 Score of 0.83 and MAE of 3082 on the training set, and on the validation set, it obtains an R2 Score of 0.84 and MAE of 3023. Although both models experience overfitting, the Polynomial Regression model performs significantly better than the regular Linear Regression model.

# %%
df_test
# Out:
#        age  sex  weight   bmi  hereditary_diseases  no_of_dependents  smoker
# 3884  58.0    0      60  36.5                    8                 0       0  \
# 6887  58.0    0      80  25.2                    8                 0       0
# 5677  45.0    0      82  35.8                    8                 0       0
# 4929  23.0    1      47  23.8                    8                 0       0
# 9124  19.0    1      51  27.5                    8                 0       1
# ...    ...  ...     ...   ...                  ...               ...     ...
# 5     42.0    0      89  37.9                    8                 0       0
# 2403  18.0    1      53  31.7                    8                 2       1
# 4155  48.0    1      59  36.7                    8                 1       0
# 321   50.0    1      81  36.2                    8                 0       0
# 4062  44.0    0      57  39.0                    4                 0       1
#
#       city  bloodpressure  diabetes  regular_ex  job_title    claim
# 3884     8             62         1           0         13  12235.8
# 6887    83             68         1           0         31  11837.2
# 5677    84             76         1           1          5   7731.9
# 4929    36             74         1           1          2   2395.2
# 9124    26             80         1           0          1  36219.4
# ...    ...            ...       ...         ...        ...      ...
# 5        1             78         0           0         12   6474.0
# 2403    32             88         1           0         33  34303.2
# 4155    86             70         1           0         28  28468.9
# 321     75             96         0           0         20   8457.8
# 4062    46             65         1           0         28  42983.5
#
# [557 rows x 13 columns]

# %%
# Split Features and Target
X_test = df_test[final_features]
y_test = df_test.claim

# Predict X_test Using Polynomial Regression
pred = poly.predict(X_test)

# Create DataFrame
predictions = df_test.copy()
predictions['predictions'] = pred
predictions.head(10)
# Out:
#         age  sex  weight   bmi  hereditary_diseases  no_of_dependents  smoker
# 3884   58.0    0      60  36.5                    8                 0       0  \
# 6887   58.0    0      80  25.2                    8                 0       0
# 5677   45.0    0      82  35.8                    8                 0       0
# 4929   23.0    1      47  23.8                    8                 0       0
# 9124   19.0    1      51  27.5                    8                 0       1
# 6011   23.0    1      65  37.1                    8                 3       0
# 5599   55.0    0      74  35.2                    8                 0       1
# 711    28.0    1      81  38.1                    8                 0       0
# 472    48.0    0      67  33.1                    0                 0       1
# 10980  45.0    0      85  27.6                    8                 1       0
#
#        city  bloodpressure  diabetes  regular_ex  job_title    claim
# 3884      8             62         1           0         13  12235.8  \
# 6887     83             68         1           0         31  11837.2
# 5677     84             76         1           1          5   7731.9
# 4929     36             74         1           1          2   2395.2
# 9124     26             80         1           0          1  36219.4
# 6011     40              0         0           0         33   3597.6
# 5599     88             80         1           0          5  44423.8
# 711      74             76         0           0         22   2689.5
# 472      15             70         1           0         24  40974.2
# 10980    42             66         0           1         20  28340.2
#
#         predictions
# 3884   13324.562500
# 6887   12169.622559
# 5677    9953.128418
# 4929    2098.751465
# 9124   24275.996582
# 6011    5166.624023
# 5599   45226.486328
# 711     2439.782227
# 472    38352.575684
# 10980  11575.923340

# %%
print('-----------Testing Set-----------')
print(f'Score: {poly.score(X_test, y_test):.2f}')
print(f'MAE: {mean_absolute_error(y_test, poly.predict(X_test)):.2f}')
# Out:
# -----------Testing Set-----------
# Score: 0.86
# MAE: 3061.70

# %% [markdown]
# ### Conclusion
# * The conclusion that can be drawn from this project is:
#
# * In this project, the dataset used consists of customer data from an insurance company with the aim of creating a machine learning model that can predict the claims paid by a customer. From the exploratory data analysis (EDA), it is found that the average claim paid by customer is dollar13,431, which is highly influenced by whether a customer is a smoker or not. Smokers account for only about 20% of the clients but have significantly higher claims, around dollar 32,120, compared to non-smokers who only pay around dollar 8,745.
#
# * However, these costs are also affected by other factors such as age and body mass index (BMI). The older the client or the higher their BMI, the higher the costs they have to pay. The average age of the clients in the dataset is 40 years, although most of the clients are in their twenties, and the average BMI is around 30 kg/m2.
#
# * Based on the EDA results, three regression models were created: Linear Regression, Polynomial Regression. All models were trained using features that can affect the "claim" column, namely age, BMI, and smoker status. The models were then evaluated, with the Linear Regression model achieving the lowest score, with an R2 Score of 0.73 and MAE of 4313 on the training set, while the Polynomial Regression model achieved the highest score, with an R2 Score of 0.86 and MAE of 3061.
#
# * Therefore, among the two models created in this project, the Polynomial Regression model with a hyperparameter degree of 3 performs the best for the given dataset.
